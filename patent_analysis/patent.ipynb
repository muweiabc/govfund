# %%
import pandas as pd
import numpy as np

# %%
invest_df = pd.read_excel('govfund_filtered.xlsx')
# invest_df = invest_df.dropna(subset=['省份'])
# with pd.ExcelWriter(excel_filename, engine='openpyxl') as writer:
# invest_df.to_excel('regress_data_with_gdp.xlsx',sheet_name='回归数据')

# %%
df = pd.read_csv('data/trimpatent_all.csv')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1468\3646036610.py:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/trimpatent_all.csv')

# %%
df.shape
df.head()
# Out:
#    Unnamed: 0  专利类型  申请人    申请年份  公开公告年份 被引证次数
# 0           0  发明申请  吴正德  1999.0  2020.0   NaN
# 1           1  发明申请  吴正德  1999.0  2020.0   NaN
# 2           2  发明申请  吴正德  1999.0  2020.0   NaN
# 3           3  发明申请  吴正德  1999.0  2020.0   NaN
# 4           4  发明申请  吴正德  1999.0  2020.0   NaN

# %%
df['专利类型'].value_counts()
# Out:
# 专利类型
# 实用新型                    20501518
# 发明申请                    16314392
# 外观设计                     8062036
# 发明授权                     5135736
# 官网：www.macrodatas.cn          44
# Name: count, dtype: int64

# %%
patent = pd.read_csv('中国专利数据库2005年.csv')
patent.head()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1468\2097041834.py:1: DtypeWarning: Columns (34) have mixed types. Specify dtype option on import or set low_memory=False.
#   patent = pd.read_csv('中国专利数据库2005年.csv')
#                 专利名称  专利类型                     申请人 申请人类型  \
# 0         悬挂组合式自动燃气炉  发明授权                     凌安国    个人
# 1       一种前后用步双驱动自行车  发明授权                孟杰君; 梁秀芝    个人
# 2    可用于游泳等的组合式流动液体槽  发明授权                      许青    个人
# 3  山楂型核酸复合剂及其生产方法和用途  发明授权  杨秉渊; 王中侃; 戴连; 陈孝华; 林祥琼    个人
# 4   人参黄芪型核酸复合剂及其生产方法  发明授权  杨秉渊; 王中侃; 戴连; 陈孝华; 林祥琼    个人
#
#                                     申请人地址 申请人地区 申请人城市 申请人区县           申请号  \
# 0  421002湖南省衡阳市江东区苗卜加树里84号衡阳铁路装卸机械厂劳动服务公司    中国   衡阳市   珠晖区  CN92109218.0
# 1          157421黑龙江省宁安市东京城林业局职工医院手术室孟丽茹转    中国  牡丹江市   宁安市  CN92112099.0
# 2          100091北京市海淀区中央党校南院新2楼1单元202号许青    中国   北京市   海淀区  CN93103794.8
# 3            350011福建省福州市连江路福州二化宿舍17幢302室    中国   福州市   连江县  CN93103202.4
# 4            350011福建省福州市连江路福州二化宿舍17幢302室    中国   福州市   连江县  CN93103201.6
#
#           申请日  ...  统一社会信用代码 引证次数 被引证次数  自引次数 他引次数 被自引次数  被他引次数 家族引证次数  \
# 0  1992-08-01  ...       NaN  NaN   NaN   NaN  NaN   NaN    NaN    NaN
# 1  1992-09-26  ...       NaN  NaN   5.0   NaN  NaN   NaN    5.0    NaN
# 2  1993-04-22  ...       NaN  2.0   7.0   NaN  2.0   7.0    NaN    3.0
# 3  1993-03-16  ...       NaN  1.0   NaN   1.0  NaN   NaN    NaN    1.0
# 4  1993-03-16  ...       NaN  1.0   NaN   1.0  NaN   NaN    NaN    1.0
#
#   家族被引证次数 Unnamed: 34
# 0     2.0         NaN
# 1     6.0         NaN
# 2     7.0         NaN
# 3     NaN         NaN
# 4     2.0         NaN
#
# [5 rows x 35 columns]

# %%
patent['专利类型'].value_counts()
# Out:
# 专利类型
# 实用新型                    81956
# 发明申请                    73826
# 外观设计                    70641
# 发明授权                    19739
# 官网：www.macrodatas.cn        1
# Name: count, dtype: int64

# %%
df
# Out:
#                 专利名称  专利类型                     申请人 申请人类型  \
# 0         悬挂组合式自动燃气炉  发明授权                     凌安国    个人
# 1       一种前后用步双驱动自行车  发明授权                孟杰君; 梁秀芝    个人
# 2    可用于游泳等的组合式流动液体槽  发明授权                      许青    个人
# 3  山楂型核酸复合剂及其生产方法和用途  发明授权  杨秉渊; 王中侃; 戴连; 陈孝华; 林祥琼    个人
# 4   人参黄芪型核酸复合剂及其生产方法  发明授权  杨秉渊; 王中侃; 戴连; 陈孝华; 林祥琼    个人
#
#                                     申请人地址 申请人地区 申请人城市 申请人区县           申请号  \
# 0  421002湖南省衡阳市江东区苗卜加树里84号衡阳铁路装卸机械厂劳动服务公司    中国   衡阳市   珠晖区  CN92109218.0
# 1          157421黑龙江省宁安市东京城林业局职工医院手术室孟丽茹转    中国  牡丹江市   宁安市  CN92112099.0
# 2          100091北京市海淀区中央党校南院新2楼1单元202号许青    中国   北京市   海淀区  CN93103794.8
# 3            350011福建省福州市连江路福州二化宿舍17幢302室    中国   福州市   连江县  CN93103202.4
# 4            350011福建省福州市连江路福州二化宿舍17幢302室    中国   福州市   连江县  CN93103201.6
#
#           申请日  ...  统一社会信用代码 引证次数 被引证次数  自引次数 他引次数 被自引次数  被他引次数 家族引证次数  \
# 0  1992-08-01  ...       NaN  NaN   NaN   NaN  NaN   NaN    NaN    NaN
# 1  1992-09-26  ...       NaN  NaN   5.0   NaN  NaN   NaN    5.0    NaN
# 2  1993-04-22  ...       NaN  2.0   7.0   NaN  2.0   7.0    NaN    3.0
# 3  1993-03-16  ...       NaN  1.0   NaN   1.0  NaN   NaN    NaN    1.0
# 4  1993-03-16  ...       NaN  1.0   NaN   1.0  NaN   NaN    NaN    1.0
#
#   家族被引证次数 Unnamed: 34
# 0     2.0         NaN
# 1     6.0         NaN
# 2     7.0         NaN
# 3     NaN         NaN
# 4     2.0         NaN
#
# [5 rows x 35 columns]

# %%
patent.columns
# Out:
# Index(['专利名称', '专利类型', '申请人', '申请人类型', '申请人地址', '申请人地区', '申请人城市', '申请人区县',
#        '申请号', '申请日', '申请年份', '公开公告号', '公开公告日', '公开公告年份', '授权公告号', '授权公告日',
#        '授权公告年份', 'IPC分类号', 'IPC主分类号', '发明人', '摘要文本', '主权项内容', '当前权利人',
#        '当前专利权人地址', '专利权人类型', '统一社会信用代码', '引证次数', '被引证次数', '自引次数', '他引次数',
#        '被自引次数', '被他引次数', '家族引证次数', '家族被引证次数', 'Unnamed: 34'],
#       dtype='object')

# %%
patent['申请人类型'].value_counts()
# Out:
# 申请人类型
# 个人                 125641
# 企业                  87626
# 学校                  20090
# 科研单位                 7895
# 企业,学校                1284
# 机关团体                 1196
# 企业,科研单位               603
# 个人,企业                 504
# 企业,个人                 458
# 科研单位,学校               188
# 个人,学校                 150
# 其他                    142
# 个人,科研单位                69
# 企业,机关团体                63
# 机关团体,学校                58
# 个人,机关团体                48
# 科研单位,机关团体              28
# 学校,企业                  20
# 企业,科研单位,学校             18
# 科研单位,机关团体,学校           14
# 其他,学校                   8
# 科研单位,企业                 6
# 个人,企业,科研单位              5
# 个人,其他                   5
# 企业,其他                   5
# 企业,个人,科研单位              4
# 企业,个人,学校                4
# 学校,个人                   4
# 其他,科研单位                 4
# 企业,机关团体,学校              4
# 企业,科研单位,机关团体,学校         3
# 学校,科研单位                 2
# 企业,科研单位,机关团体            2
# 个人,机关团体,学校              2
# 其他,机关团体                 2
# 科研单位,个人                 1
# 个人,企业,科研单位,机关团体         1
# 个人,科研单位,学校              1
# 企业,个人,机关团体,学校           1
# 企业,个人,机关团体              1
# 企业,其他,学校                1
# 个人,科研单位,机关团体            1
# Name: count, dtype: int64

# %%
df3 = pd.read_excel('govfund_filtered.xlsx')
# Out:
# 基金分类
# 产业基金      1361
# 创业投资基金     559
# --         299
# PPP        186
# Name: count, dtype: int64

# %%
df3['基金级别'].value_counts()
# Out:
# 基金级别
# 地市级    939
# 区县级    744
# 省级     388
# --     300
# 国家级     34
# Name: count, dtype: int64
